# %%
rawdata_dir = '/global/homes/h/huikong/obiwan_test/obiwan_eboss/data/rawdata/'
import astropy.io.fits as fits
ran = fits.open(rawdata_dir+'randoms_subset_of_columns.fits')[1].data
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(ran['ra'],ran['dec'],'r,')

dat = fits.open(rawdata_dir+'ELGNGCtestfull.dat.fits')[1].data
plt.plot(dat['ra'],dat['dec'],'g,',alpha=0.2)

plt.xlim((122,168))
plt.ylim((12,34))
# Out:
# (12, 34)
